# %%
# !pip install flask flask-cors pillow python-docx PyPDF2 sentence-transformers chromadb easyocr
# Out:
# Requirement already satisfied: flask in c:\users\benky\anaconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: flask-cors in c:\users\benky\anaconda3\lib\site-packages (6.0.2)
# Requirement already satisfied: pillow in c:\users\benky\anaconda3\lib\site-packages (12.0.0)
# Requirement already satisfied: python-docx in c:\users\benky\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: PyPDF2 in c:\users\benky\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: sentence-transformers in c:\users\benky\anaconda3\lib\site-packages (5.3.0)
# Requirement already satisfied: chromadb in c:\users\benky\anaconda3\lib\site-packages (1.5.6)
# Requirement already satisfied: easyocr in c:\users\benky\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\benky\anaconda3\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\benky\anaconda3\lib\site-packages (from flask) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\benky\anaconda3\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\benky\anaconda3\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\benky\anaconda3\lib\site-packages (from flask) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\benky\anaconda3\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\benky\anaconda3\lib\site-packages (from python-docx) (5.3.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\benky\anaconda3\lib\site-packages (from python-docx) (4.15.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\benky\anaconda3\lib\site-packages (from sentence-transformers) (5.1.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\benky\anaconda3\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\benky\anaconda3\lib\site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: numpy in c:\users\benky\anaconda3\lib\site-packages (from sentence-transformers) (2.3.5)
# Requirement already satisfied: scikit-learn in c:\users\benky\anaconda3\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\benky\anaconda3\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: tqdm in c:\users\benky\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\benky\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\benky\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\benky\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.3.32)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\benky\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\benky\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\benky\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\benky\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\benky\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\benky\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\benky\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: typer in c:\users\benky\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: anyio in c:\users\benky\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\benky\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\benky\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\benky\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\benky\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: pydantic>=2.0 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (2.12.4)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (2.12.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\benky\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.44.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (3.11.8)
# Requirement already satisfied: rich>=10.11.0 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\benky\anaconda3\lib\site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: torchvision>=0.5 in c:\users\benky\anaconda3\lib\site-packages (from easyocr) (0.26.0)
# Requirement already satisfied: opencv-python-headless in c:\users\benky\anaconda3\lib\site-packages (from easyocr) (4.13.0.92)
# Requirement already satisfied: scikit-image in c:\users\benky\anaconda3\lib\site-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in c:\users\benky\anaconda3\lib\site-packages (from easyocr) (0.6.7)
# Requirement already satisfied: Shapely in c:\users\benky\anaconda3\lib\site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in c:\users\benky\anaconda3\lib\site-packages (from easyocr) (1.4.0)
# Requirement already satisfied: ninja in c:\users\benky\anaconda3\lib\site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: pyproject_hooks in c:\users\benky\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\benky\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\benky\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\benky\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\benky\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\benky\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\benky\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\benky\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\benky\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\benky\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Requirement already satisfied: requests-oauthlib in c:\users\benky\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\benky\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\benky\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in c:\users\benky\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\benky\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: sympy in c:\users\benky\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\benky\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\benky\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\benky\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in c:\users\benky\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in c:\users\benky\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in c:\users\benky\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\benky\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\benky\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\benky\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\benky\anaconda3\lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\benky\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\benky\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\benky\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: setuptools<82 in c:\users\benky\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\benky\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\benky\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\benky\anaconda3\lib\site-packages (from typer->huggingface-hub>=0.20.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\benky\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\benky\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\benky\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\benky\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\benky\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\benky\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\benky\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\benky\anaconda3\lib\site-packages (from scikit-image->easyocr) (2025.10.4)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\benky\anaconda3\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\benky\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\benky\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)

# %%
# OPTIONAL: remove previous upload documents
import shutil
import os

# Delete the database folder
if os.path.exists("./chroma_db"):
    shutil.rmtree("./chroma_db")
    print("✅ Deleted old database")
else:
    print("No database found")
# Out:
# ✅ Deleted old database

# %%
import threading
import webbrowser
import time
from flask_app import run_flask
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Start Flask in background
server_thread = threading.Thread(target=run_flask, daemon=True)
server_thread.start()

# Wait for server to start
time.sleep(3)
# Out:
#  * Serving Flask app 'flask_app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.68.61:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [18/Apr/2026 20:18:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2026 20:19:20] "POST /search HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2026 20:19:26] "POST /upload HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2026 20:19:30] "POST /upload HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2026 20:19:33] "POST /upload HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2026 20:19:39] "POST /search HTTP/1.1" 200 -

# %%
# Open browser
webbrowser.open('http://localhost:5000')

print("""
========================================
✅ Server is running!
📱 Open: http://localhost:5000
🛑 Press Stop in Jupyter to quit
========================================
""")
# Out:
# ========================================
# ✅ Server is running!
# 📱 Open: http://localhost:5000
# 🛑 Press Stop in Jupyter to quit
# ========================================

# %%
import time
try:
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    print("\nServer stopped")
